# %% [markdown]
# ![ine-divider](https://user-images.githubusercontent.com/7065401/92672068-398e8080-f2ee-11ea-82d6-ad53f7feb5c0.png)
# <hr>
#
# ### GitHub and Version Control
# # Practicing Forking and Pull Requests
#
# This project will have somewhat unusual requirements among INE data science courses.  Most such projects ask you to complete cells in a notebook such as this.  However, this project will predominantly involve working at the command line.
#
# There *does* exist a bash kernel for Jupyter, which this notebook is saved as. To install it execute in your terminal:
#
# ```
# pip install bash_kernel
# python -m bash_kernel.install
# ```
#
# and restart your Notebook.
#
# However, the kinds of interactivity you have at a shell are much more flexible than in a notebook.  However, you *can* run bash commands if you install that Jupyter kernel. E.g.:

# %%
git --version
# Out:
# git version 2.27.0

# %% [markdown]
# ![orange-divider](https://user-images.githubusercontent.com/7065401/92672455-187a5f80-f2ef-11ea-890c-40be9474f7b7.png)

# %% [markdown]
# ## Part 1
#
# **Fork the Fractal Repository**
#
# For this exercerise, you should fork the repository at https://github.com/ine-rmotr-projects/Fractal which was created in this lesson.
#
# In order to do this you will need to create an account and setup your security credentials.  If you already have a GitHub account, you may have performed some of the steps already.
#
# * For the repository.
# * In its original form, the repository contains numbered directories under its `versions/` directory that reflect various changes made to the library.  You wish to transform this into actual branches and versions instead.
# * Within your fork, create separate branches corresponding to the numbered directories.  You may simply use numeric names for the branches, or may select something more descriptive for each.
# * Each branch in your fork should contain **only** those files used in that version of the library.

# %% [markdown]
# **Solution**

# %%
# At the GitHub website, for the repository
# clone your personal version...
cd ~/tmp
git clone git@github.com:ine-rmotr-projects/Fractal.git
cd Fractal

git checkout -B 01 main
git mv versions/01/* .
git rm -rf versions/
git commit -m "Create branch 01"
git push --set-upstream origin 01

git checkout -B 02 main
git mv versions/02/* .
git rm -rf versions/
git commit -m "Create branch 02"
git push --set-upstream origin 02

# ... etc ...
# Out:
# Cloning into 'Fractal'...
# remote: Enumerating objects: 75, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 75 (delta 27), reused 72 (delta 25), pack-reused 0
# Receiving objects: 100% (75/75), 1.28 MiB | 2.17 MiB/s, done.
# Resolving deltas: 100% (27/27), done.
# Switched to a new branch '01'
# rm 'versions/02/fractal/__init__.py'
# rm 'versions/02/fractal/julia.py'
# rm 'versions/02/fractal/koch.py'
# rm 'versions/02/fractal/mandelbrot.py'
# rm 'versions/02/fractal/sierpiński.py'
# rm 'versions/02/fractal/visualize.py'
# rm 'versions/02/test/__init__.py'
# rm 'versions/02/test/test_canvas_A.py'
# rm 'versions/02/test/test_canvas_B.py'
# rm 'versions/02/test/test_canvas_C.py'
# rm 'versions/02/test/test_points.py'
# rm 'versions/03/fractal/__init__.py'
# rm 'versions/03/fractal/julia.py'
# rm 'versions/03/fractal/koch.py'
# rm 'versions/03/fractal/mandelbrot.py'
# rm 'versions/03/fractal/sierpiński.py'
# rm 'versions/03/fractal/visualize.py'
# rm 'versions/03/test/__init__.py'
# rm 'versions/03/test/test_canvas.py'
# rm 'versions/03/test/test_points.py'
# rm 'versions/04/Mandelbrot.md'
# rm 'versions/04/fractal/__init__.py'
# rm 'versions/04/fractal/julia.py'
# rm 'versions/04/fractal/koch.py'
# rm 'versions/04/fractal/mandelbrot.py'
# rm 'versions/04/fractal/sierpiński.py'
# rm 'versions/04/fractal/visualize.py'
# rm 'versions/04/test/__init__.py'
# rm 'versions/04/test/test_canvas.py'
# rm 'versions/04/test/test_failure.py'
# rm 'versions/04/test/test_points.py'
# rm 'versions/04/test/test_visualize.py'
# rm 'versions/04/test_failure.out'
# rm 'versions/05/Mandelbrot.md'
# rm 'versions/05/fractal/__init__.py'
# rm 'versions/05/fractal/julia.py'
# rm 'versions/05/fractal/koch.py'
# rm 'versions/05/fractal/mandelbrot.py'
# rm 'versions/05/fractal/sequences.py'
# rm 'versions/05/fractal/sierpiński.py'
# rm 'versions/05/fractal/visualize.py'
# rm 'versions/05/server/number_server.py'
# rm 'versions/05/server/primes.pkl.gz'
# rm 'versions/05/test/__init__.py'
# rm 'versions/05/test/test_canvas.py'
# rm 'versions/05/test/test_failure.py'
# rm 'versions/05/test/test_fixture.py'
# rm 'versions/05/test/test_numbers.py'
# rm 'versions/05/test/test_points.py'
# rm 'versions/05/test/test_visualize.py'
# rm 'versions/05/test_failure.out'
# rm 'versions/06/Mandelbrot.md'
# rm 'versions/06/fractal/__init__.py'
# rm 'versions/06/fractal/julia.py'
# rm 'versions/06/fractal/koch.py'
# rm 'versions/06/fractal/mandelbrot.py'
# rm 'versions/06/fractal/sequences.py'
# rm 'versions/06/fractal/sierpiński.py'
# rm 'versions/06/fractal/visualize.py'
# rm 'versions/06/server/number_server.py'
# rm 'versions/06/server/primes.pkl.gz'
# rm 'versions/06/test/__init__.py'
# rm 'versions/06/test/test_archives.py'
# rm 'versions/06/test/test_canvas.py'
# rm 'versions/06/test/test_failure.py'
# rm 'versions/06/test/test_fixture.py'
# rm 'versions/06/test/test_numbers.py'
# rm 'versions/06/test/test_points.py'
# rm 'versions/06/test/test_visualize.py'
# rm 'versions/06/test_failure.out'
# rm 'versions/06/utility/exchange.py'
# [01 2ae0896] Create branch 01
#  76 files changed, 2408 deletions(-)
#  rename versions/01/Mandelbrot.md => Mandelbrot.md (100%)
#  rename versions/01/mandelbrot-1.py => mandelbrot-1.py (100%)
#  rename versions/01/mandelbrot-2.py => mandelbrot-2.py (100%)
#  rename versions/01/mandelbrot-3.py => mandelbrot-3.py (100%)
#  delete mode 100644 versions/02/fractal/__init__.py
#  delete mode 100644 versions/02/fractal/julia.py
#  delete mode 100644 versions/02/fractal/koch.py
#  delete mode 100644 versions/02/fractal/mandelbrot.py
#  delete mode 100644 "versions/02/fractal/sierpi\305\204ski.py"
#  delete mode 100644 versions/02/fractal/visualize.py
#  delete mode 100644 versions/02/test/__init__.py
#  delete mode 100644 versions/02/test/test_canvas_A.py
#  delete mode 100644 versions/02/test/test_canvas_B.py
#  delete mode 100644 versions/02/test/test_canvas_C.py
#  delete mode 100644 versions/02/test/test_points.py
#  delete mode 100644 versions/03/fractal/__init__.py
#  delete mode 100644 versions/03/fractal/julia.py
#  delete mode 100644 versions/03/fractal/koch.py
#  delete mode 100644 versions/03/fractal/mandelbrot.py
#  delete mode 100644 "versions/03/fractal/sierpi\305\204ski.py"
#  delete mode 100644 versions/03/fractal/visualize.py
#  delete mode 100644 versions/03/test/__init__.py
#  delete mode 100644 versions/03/test/test_canvas.py
#  delete mode 100644 versions/03/test/test_points.py
#  delete mode 100644 versions/04/Mandelbrot.md
#  delete mode 100644 versions/04/fractal/__init__.py
#  delete mode 100644 versions/04/fractal/julia.py
#  delete mode 100644 versions/04/fractal/koch.py
#  delete mode 100644 versions/04/fractal/mandelbrot.py
#  delete mode 100644 "versions/04/fractal/sierpi\305\204ski.py"
#  delete mode 100644 versions/04/fractal/visualize.py
#  delete mode 100644 versions/04/test/__init__.py
#  delete mode 100644 versions/04/test/test_canvas.py
#  delete mode 100644 versions/04/test/test_failure.py
#  delete mode 100644 versions/04/test/test_points.py
#  delete mode 100644 versions/04/test/test_visualize.py
#  delete mode 100644 versions/04/test_failure.out
#  delete mode 100644 versions/05/Mandelbrot.md
#  delete mode 100644 versions/05/fractal/__init__.py
#  delete mode 100644 versions/05/fractal/julia.py
#  delete mode 100644 versions/05/fractal/koch.py
#  delete mode 100644 versions/05/fractal/mandelbrot.py
#  delete mode 100644 versions/05/fractal/sequences.py
#  delete mode 100644 "versions/05/fractal/sierpi\305\204ski.py"
#  delete mode 100644 versions/05/fractal/visualize.py
#  delete mode 100644 versions/05/server/number_server.py
#  delete mode 100644 versions/05/server/primes.pkl.gz
#  delete mode 100644 versions/05/test/__init__.py
#  delete mode 100644 versions/05/test/test_canvas.py
#  delete mode 100644 versions/05/test/test_failure.py
#  delete mode 100644 versions/05/test/test_fixture.py
#  delete mode 100644 versions/05/test/test_numbers.py
#  delete mode 100644 versions/05/test/test_points.py
#  delete mode 100644 versions/05/test/test_visualize.py
#  delete mode 100644 versions/05/test_failure.out
#  delete mode 100644 versions/06/Mandelbrot.md
#  delete mode 100644 versions/06/fractal/__init__.py
#  delete mode 100644 versions/06/fractal/julia.py
#  delete mode 100644 versions/06/fractal/koch.py
#  delete mode 100644 versions/06/fractal/mandelbrot.py
#  delete mode 100644 versions/06/fractal/sequences.py
#  delete mode 100644 "versions/06/fractal/sierpi\305\204ski.py"
#  delete mode 100644 versions/06/fractal/visualize.py
#  delete mode 100644 versions/06/server/number_server.py
#  delete mode 100644 versions/06/server/primes.pkl.gz
#  delete mode 100644 versions/06/test/__init__.py
#  delete mode 100644 versions/06/test/test_archives.py
#  delete mode 100644 versions/06/test/test_canvas.py
#  delete mode 100644 versions/06/test/test_failure.py
#  delete mode 100644 versions/06/test/test_fixture.py
#  delete mode 100644 versions/06/test/test_numbers.py
#  delete mode 100644 versions/06/test/test_points.py
#  delete mode 100644 versions/06/test/test_visualize.py
#  delete mode 100644 versions/06/test_failure.out
#  delete mode 100644 versions/06/utility/exchange.py
#  rename versions/01/visualize.py => visualize.py (100%)
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 8 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (7/7), 2.06 KiB | 2.06 MiB/s, done.
# Total 7 (delta 2), reused 3 (delta 2), pack-reused 0
# remote: Resolving deltas: 100% (2/2), done.
# remote:
# remote: Create a pull request for '01' on GitHub by visiting:
# remote:      https://github.com/DavidMertz/Fractal/pull/new/01
# remote:
# To github.com:DavidMertz/Fractal.git
#  * [new branch]      01 -> 01
# Branch '01' set up to track remote branch '01' from 'origin'.
# Switched to a new branch '02'
# rm 'versions/01/Mandelbrot.md'
# rm 'versions/01/mandelbrot-1.py'
# rm 'versions/01/mandelbrot-2.py'
# rm 'versions/01/mandelbrot-3.py'
# rm 'versions/01/visualize.py'
# rm 'versions/03/fractal/__init__.py'
# rm 'versions/03/fractal/julia.py'
# rm 'versions/03/fractal/koch.py'
# rm 'versions/03/fractal/mandelbrot.py'
# rm 'versions/03/fractal/sierpiński.py'
# rm 'versions/03/fractal/visualize.py'
# rm 'versions/03/test/__init__.py'
# rm 'versions/03/test/test_canvas.py'
# rm 'versions/03/test/test_points.py'
# rm 'versions/04/Mandelbrot.md'
# rm 'versions/04/fractal/__init__.py'
# rm 'versions/04/fractal/julia.py'
# rm 'versions/04/fractal/koch.py'
# rm 'versions/04/fractal/mandelbrot.py'
# rm 'versions/04/fractal/sierpiński.py'
# rm 'versions/04/fractal/visualize.py'
# rm 'versions/04/test/__init__.py'
# rm 'versions/04/test/test_canvas.py'
# rm 'versions/04/test/test_failure.py'
# rm 'versions/04/test/test_points.py'
# rm 'versions/04/test/test_visualize.py'
# rm 'versions/04/test_failure.out'
# rm 'versions/05/Mandelbrot.md'
# rm 'versions/05/fractal/__init__.py'
# rm 'versions/05/fractal/julia.py'
# rm 'versions/05/fractal/koch.py'
# rm 'versions/05/fractal/mandelbrot.py'
# rm 'versions/05/fractal/sequences.py'
# rm 'versions/05/fractal/sierpiński.py'
# rm 'versions/05/fractal/visualize.py'
# rm 'versions/05/server/number_server.py'
# rm 'versions/05/server/primes.pkl.gz'
# rm 'versions/05/test/__init__.py'
# rm 'versions/05/test/test_canvas.py'
# rm 'versions/05/test/test_failure.py'
# rm 'versions/05/test/test_fixture.py'
# rm 'versions/05/test/test_numbers.py'
# rm 'versions/05/test/test_points.py'
# rm 'versions/05/test/test_visualize.py'
# rm 'versions/05/test_failure.out'
# rm 'versions/06/Mandelbrot.md'
# rm 'versions/06/fractal/__init__.py'
# rm 'versions/06/fractal/julia.py'
# rm 'versions/06/fractal/koch.py'
# rm 'versions/06/fractal/mandelbrot.py'
# rm 'versions/06/fractal/sequences.py'
# rm 'versions/06/fractal/sierpiński.py'
# rm 'versions/06/fractal/visualize.py'
# rm 'versions/06/server/number_server.py'
# rm 'versions/06/server/primes.pkl.gz'
# rm 'versions/06/test/__init__.py'
# rm 'versions/06/test/test_archives.py'
# rm 'versions/06/test/test_canvas.py'
# rm 'versions/06/test/test_failure.py'
# rm 'versions/06/test/test_fixture.py'
# rm 'versions/06/test/test_numbers.py'
# rm 'versions/06/test/test_points.py'
# rm 'versions/06/test/test_visualize.py'
# rm 'versions/06/test_failure.out'
# rm 'versions/06/utility/exchange.py'
# [02 9bf9b16] Create branch 02
#  76 files changed, 2245 deletions(-)
#  rename {versions/02/fractal => fractal}/__init__.py (100%)
#  rename {versions/02/fractal => fractal}/julia.py (100%)
#  rename {versions/02/fractal => fractal}/koch.py (100%)
#  rename {versions/02/fractal => fractal}/mandelbrot.py (100%)
#  rename "versions/02/fractal/sierpi\305\204ski.py" => "fractal/sierpi\305\204ski.py" (100%)
#  rename {versions/02/fractal => fractal}/visualize.py (100%)
#  rename {versions/02/test => test}/__init__.py (100%)
#  rename {versions/02/test => test}/test_canvas_A.py (100%)
#  rename {versions/02/test => test}/test_canvas_B.py (100%)
#  rename {versions/02/test => test}/test_canvas_C.py (100%)
#  rename {versions/02/test => test}/test_points.py (100%)
#  delete mode 100644 versions/01/Mandelbrot.md
#  delete mode 100644 versions/01/mandelbrot-1.py
#  delete mode 100644 versions/01/mandelbrot-2.py
#  delete mode 100644 versions/01/mandelbrot-3.py
#  delete mode 100644 versions/01/visualize.py
#  delete mode 100644 versions/03/fractal/__init__.py
#  delete mode 100644 versions/03/fractal/julia.py
#  delete mode 100644 versions/03/fractal/koch.py
#  delete mode 100644 versions/03/fractal/mandelbrot.py
#  delete mode 100644 "versions/03/fractal/sierpi\305\204ski.py"
#  delete mode 100644 versions/03/fractal/visualize.py
#  delete mode 100644 versions/03/test/__init__.py
#  delete mode 100644 versions/03/test/test_canvas.py
#  delete mode 100644 versions/03/test/test_points.py
#  delete mode 100644 versions/04/Mandelbrot.md
#  delete mode 100644 versions/04/fractal/__init__.py
#  delete mode 100644 versions/04/fractal/julia.py
#  delete mode 100644 versions/04/fractal/koch.py
#  delete mode 100644 versions/04/fractal/mandelbrot.py
#  delete mode 100644 "versions/04/fractal/sierpi\305\204ski.py"
#  delete mode 100644 versions/04/fractal/visualize.py
#  delete mode 100644 versions/04/test/__init__.py
#  delete mode 100644 versions/04/test/test_canvas.py
#  delete mode 100644 versions/04/test/test_failure.py
#  delete mode 100644 versions/04/test/test_points.py
#  delete mode 100644 versions/04/test/test_visualize.py
#  delete mode 100644 versions/04/test_failure.out
#  delete mode 100644 versions/05/Mandelbrot.md
#  delete mode 100644 versions/05/fractal/__init__.py
#  delete mode 100644 versions/05/fractal/julia.py
#  delete mode 100644 versions/05/fractal/koch.py
#  delete mode 100644 versions/05/fractal/mandelbrot.py
#  delete mode 100644 versions/05/fractal/sequences.py
#  delete mode 100644 "versions/05/fractal/sierpi\305\204ski.py"
#  delete mode 100644 versions/05/fractal/visualize.py
#  delete mode 100644 versions/05/server/number_server.py
#  delete mode 100644 versions/05/server/primes.pkl.gz
#  delete mode 100644 versions/05/test/__init__.py
#  delete mode 100644 versions/05/test/test_canvas.py
#  delete mode 100644 versions/05/test/test_failure.py
#  delete mode 100644 versions/05/test/test_fixture.py
#  delete mode 100644 versions/05/test/test_numbers.py
#  delete mode 100644 versions/05/test/test_points.py
#  delete mode 100644 versions/05/test/test_visualize.py
#  delete mode 100644 versions/05/test_failure.out
#  delete mode 100644 versions/06/Mandelbrot.md
#  delete mode 100644 versions/06/fractal/__init__.py
#  delete mode 100644 versions/06/fractal/julia.py
#  delete mode 100644 versions/06/fractal/koch.py
#  delete mode 100644 versions/06/fractal/mandelbrot.py
#  delete mode 100644 versions/06/fractal/sequences.py
#  delete mode 100644 "versions/06/fractal/sierpi\305\204ski.py"
#  delete mode 100644 versions/06/fractal/visualize.py
#  delete mode 100644 versions/06/server/number_server.py
#  delete mode 100644 versions/06/server/primes.pkl.gz
#  delete mode 100644 versions/06/test/__init__.py
#  delete mode 100644 versions/06/test/test_archives.py
#  delete mode 100644 versions/06/test/test_canvas.py
#  delete mode 100644 versions/06/test/test_failure.py
#  delete mode 100644 versions/06/test/test_fixture.py
#  delete mode 100644 versions/06/test/test_numbers.py
#  delete mode 100644 versions/06/test/test_points.py
#  delete mode 100644 versions/06/test/test_visualize.py
#  delete mode 100644 versions/06/test_failure.out
#  delete mode 100644 versions/06/utility/exchange.py
# Enumerating objects: 14, done.
# Counting objects: 100% (14/14), done.
# Delta compression using up to 8 threads
# Compressing objects: 100% (11/11), done.
# Writing objects: 100% (13/13), 3.60 KiB | 3.60 MiB/s, done.
# Total 13 (delta 3), reused 6 (delta 1), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 1 local object.
# remote:
# remote: Create a pull request for '02' on GitHub by visiting:
# remote:      https://github.com/DavidMertz/Fractal/pull/new/02
# remote:
# To github.com:DavidMertz/Fractal.git
#  * [new branch]      02 -> 02
# Branch '02' set up to track remote branch '02' from 'origin'.

# %% [markdown]
# ![orange-divider](https://user-images.githubusercontent.com/7065401/92672455-187a5f80-f2ef-11ea-890c-40be9474f7b7.png)
#
# ## Part 2
#
# **Pull Requests**
#
# Within your favorite branch of your personal fork of the `Fractal` repository, add a new fractal function.
#
# If you are not a Python programmer, or do not want to think that much about the mathematical algorithms, finding an existing sample from a web search is perfectly fine.  Thousands of people have written functions to implement various fractals.  You simply want one or more new files containing one or more new functions you have created.
#
# Using your new branch with your new functionality, propose a change to `ine-rmotr-projects/Fractal`, but specifically to the `projects` branch of that repository.  Provide a general description of what you have added and examine the changes that are involved in your proposed change.
#
# As time and attention allow, I may comment on your pull request.  But you should be able to view it in any case.  Please do not make pull requests against the `main` branch.  They are easy to delete, but understanding different workflows is the main point of this task.

# %% [markdown]
# ![orange-divider](https://user-images.githubusercontent.com/7065401/92672455-187a5f80-f2ef-11ea-890c-40be9474f7b7.png)
